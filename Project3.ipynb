# %% [markdown]
# <a href="https://colab.research.google.com/github/dhuynh1182/rat1.3/blob/main/Project3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.4/660.4 kB 5.3 MB/s eta 0:00:00
# ...

# %%
import cv2 as cv
import numpy as np
import PIL
import torch
import ultralytics
from matplotlib import pyplot as plt

#mounting drive to colab
from google.colab import drive

drive.mount('/content/drive')

img1 = cv.imread('/content/drive/MyDrive/motherboard_image.JPEG', cv.IMREAD_GRAYSCALE)

assert img1 is not None, "check file path"

img = cv.medianBlur(img1,5)

ret,th1 = cv.threshold(img,150,255,cv.THRESH_BINARY)

edges = cv.Canny(img,50,300)


plt.imshow(edges)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
